# %%
import numpy as np
import math
import random

def approximatePi(number_of_shots):
    counter = 0
    for s in range (0, number_of_shots):
        x = random.uniform(-1,1)
        y = random.uniform(-1,1)
        if (x*x + y*y <1):
            counter = counter + 1
    return 4 * counter/number_of_shots

# %%
for i in range(0,100):
    calculated_pi = approximatePi(1000)
    true_pi = np.pi
    true_error = abs(true_pi - calculated_pi)
    relative_error = abs((true_pi - calculated_pi)/true_pi)
    
    print(calculated_pi, true_error, relative_error)
    
##This is all from the class^^
# Out:
# 3.152 0.010407346410207019 0.003312761251308279
# 3.112 0.029592653589793017 0.00941963419604336
# 3.196 0.05440734641020706 0.01731839624339508
# 3.252 0.11040734641020666 0.035143749869687234
# 3.144 0.002407346410207012 0.000766282161837951
# 3.252 0.11040734641020666 0.035143749869687234
# 3.12 0.02159265358979301 0.006873155106573032
# 3.112 0.029592653589793017 0.00941963419604336
# 3.176 0.03440734641020704 0.010952198519719262
# 3.132 0.009592653589792999 0.0030534364723675406
# 3.164 0.02240734641020703 0.0071324798855137705
# 3.148 0.0064073464102070155 0.002039521706573115
# 3.06 0.08159265358979306 0.02597174827760049
# 3.16 0.018407346410207026 0.005859240340778607
# 3.172 0.030407346410207037 0.009678958974984098
# 3.14 0.0015926535897929917 0.0005069573828972128
# 3.164 0.02240734641020703 0.0071324798855137705
# 3.088 0.05359265358979304 0.01705907146445434
# 3.072 0.06959265358979305 0.022152029643394997
# 3.12 0.02159265358979301 0.006873155106573032
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(true_error, 'r--')
plt.show()
