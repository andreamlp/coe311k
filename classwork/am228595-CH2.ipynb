# %%
n = int(input("Enter a number: "))
print(bin(n))

## I used ChatGPT for this answer, this is the task I told it to do:
##how do you create a python code that takes numbers and then returns the base-2 numbers in binary
# Out:
# Enter a number: 2050
# 0b100000000010
